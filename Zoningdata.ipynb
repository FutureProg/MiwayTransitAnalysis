# %%
import geopandas as gpd
from shapely.geometry import Polygon

# %%
df1=gpd.read_file('https://services6.arcgis.com/hM5ymMLbxIyWTjn2/ArcGIS/rest/services/ZoningMap/FeatureServer/0/query?f=geojson&returnGeometry=true&spatialRel=esriSpatialRelIntersects&geometry=%7B%22xmin%22%3A-8883817.175416991%2C%22ymin%22%3A5361598.912036989%2C%22xmax%22%3A-8844681.416934991%2C%22ymax%22%3A5400734.670518989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D&geometryType=esriGeometryEnvelope&inSR=102100&outFields=*&returnCentroid=false&returnExceededLimitFeatures=false&maxRecordCountFactor=3&outSR=102100&resultType=tile&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A76.43702828515632%2C%22extent%22%3A%7B%22xmin%22%3A-8883817.175416991%2C%22ymin%22%3A5361598.912036989%2C%22xmax%22%3A-8844681.416934991%2C%22ymax%22%3A5400734.670518989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D%7D')
df2=gpd.read_file('https://services6.arcgis.com/hM5ymMLbxIyWTjn2/ArcGIS/rest/services/ZoningMap/FeatureServer/0/query?f=geojson&returnGeometry=true&spatialRel=esriSpatialRelIntersects&geometry=%7B%22xmin%22%3A-8844681.416934991%2C%22ymin%22%3A5361598.912036989%2C%22xmax%22%3A-8805545.658452991%2C%22ymax%22%3A5400734.670518989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D&geometryType=esriGeometryEnvelope&inSR=102100&outFields=*&returnCentroid=false&returnExceededLimitFeatures=false&maxRecordCountFactor=3&outSR=102100&resultType=tile&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A76.43702828515632%2C%22extent%22%3A%7B%22xmin%22%3A-8844681.416934991%2C%22ymin%22%3A5361598.912036989%2C%22xmax%22%3A-8805545.658452991%2C%22ymax%22%3A5400734.670518989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D%7D')
df3=gpd.read_file('https://services6.arcgis.com/hM5ymMLbxIyWTjn2/ArcGIS/rest/services/ZoningMap/FeatureServer/0/query?f=geojson&returnGeometry=true&spatialRel=esriSpatialRelIntersects&geometry=%7B%22xmin%22%3A-8883817.175416991%2C%22ymin%22%3A5400734.670518989%2C%22xmax%22%3A-8844681.416934991%2C%22ymax%22%3A5439870.429000989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D&geometryType=esriGeometryEnvelope&inSR=102100&outFields=*&returnCentroid=false&returnExceededLimitFeatures=false&maxRecordCountFactor=3&outSR=102100&resultType=tile&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A76.43702828515632%2C%22extent%22%3A%7B%22xmin%22%3A-8883817.175416991%2C%22ymin%22%3A5400734.670518989%2C%22xmax%22%3A-8844681.416934991%2C%22ymax%22%3A5439870.429000989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D%7D')
df4=gpd.read_file('https://services6.arcgis.com/hM5ymMLbxIyWTjn2/ArcGIS/rest/services/ZoningMap/FeatureServer/0/query?f=geojson&returnGeometry=true&spatialRel=esriSpatialRelIntersects&geometry=%7B%22xmin%22%3A-8844681.416934991%2C%22ymin%22%3A5400734.670518989%2C%22xmax%22%3A-8805545.658452991%2C%22ymax%22%3A5439870.429000989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D&geometryType=esriGeometryEnvelope&inSR=102100&outFields=*&returnCentroid=false&returnExceededLimitFeatures=false&maxRecordCountFactor=3&outSR=102100&resultType=tile&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A76.43702828515632%2C%22extent%22%3A%7B%22xmin%22%3A-8844681.416934991%2C%22ymin%22%3A5400734.670518989%2C%22xmax%22%3A-8805545.658452991%2C%22ymax%22%3A5439870.429000989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D%7D')
df5=gpd.read_file('https://services6.arcgis.com/hM5ymMLbxIyWTjn2/ArcGIS/rest/services/ZoningMap/FeatureServer/0/query?f=geojson&returnGeometry=true&spatialRel=esriSpatialRelIntersects&geometry=%7B%22xmin%22%3A-8922952.933898991%2C%22ymin%22%3A5361598.912036989%2C%22xmax%22%3A-8883817.175416991%2C%22ymax%22%3A5400734.670518989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D&geometryType=esriGeometryEnvelope&inSR=102100&outFields=*&returnCentroid=false&returnExceededLimitFeatures=false&maxRecordCountFactor=3&outSR=102100&resultType=tile&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A76.43702828515632%2C%22extent%22%3A%7B%22xmin%22%3A-8922952.933898991%2C%22ymin%22%3A5361598.912036989%2C%22xmax%22%3A-8883817.175416991%2C%22ymax%22%3A5400734.670518989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D%7D')
df6=gpd.read_file('https://services6.arcgis.com/hM5ymMLbxIyWTjn2/ArcGIS/rest/services/ZoningMap/FeatureServer/0/query?f=geojson&returnGeometry=true&spatialRel=esriSpatialRelIntersects&geometry=%7B%22xmin%22%3A-8922952.933898991%2C%22ymin%22%3A5400734.670518989%2C%22xmax%22%3A-8883817.175416991%2C%22ymax%22%3A5439870.429000989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D&geometryType=esriGeometryEnvelope&inSR=102100&outFields=*&returnCentroid=false&returnExceededLimitFeatures=false&maxRecordCountFactor=3&outSR=102100&resultType=tile&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A76.43702828515632%2C%22extent%22%3A%7B%22xmin%22%3A-8922952.933898991%2C%22ymin%22%3A5400734.670518989%2C%22xmax%22%3A-8883817.175416991%2C%22ymax%22%3A5439870.429000989%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%2C%22latestWkid%22%3A3857%7D%7D%7D')
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
df = df1.append(df2).append(df3).append(df4).append(df5).append(df6)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
# df['geometry'] = df['geometry'].apply(lambda x: Polygon(x.exterior.coords[:-1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.geos_linearring_from_py()
#
# AttributeError: 'list' object has no attribute '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-88d826e12920> in <module>
# ----> 1 df['geometry'] = df['geometry'].apply(lambda x: Polygon(x.exterior.coords[:-2]))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
# ...

# %%
is_valid = df['geometry'].apply(lambda x: x.is_valid)
df = df[is_valid]

# %%
df.shape
# Out:
# (13125, 24)

# %%
df = df.to_crs({'init': 'epsg:4326'})

# %%
df.plot(figsize=(20,20), color='blue', edgecolor='black')

# %%
df.to_file('/Users/Nick/Documents/Personal/Data/Mississauga/zoning.geojson', driver='GeoJSON')

# %%
Polygon(df['geometry'].iloc[0].exterior.coords[:-1])

# %%
from google.cloud import bigquery as bq
client = bq.Client(project='open-city-data')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-126-0e2bdbd2f62e> in <module>
# ----> 1 from google.cloud import bigquery as bq
#       2 client = bq.Client(project='open-city-data')
#
# /usr/local/lib/python3.7/site-packages/google/cloud/bigquery/__init__.py in <module>
#      29
#      30
# ---> 31 from pkg_resources import get_distribution
#      32
#      33 __version__ = get_distribution("google-cloud-bigquery").version
#
# /usr/local/lib/python3.7/site-packages/pkg_resources/__init__.py in <module>
#      33 import platform
#      34 import collections
# ---> 35 import plistlib
#      36 import email.parser
#      37 import errno
#
# ModuleNotFoundError: No module named 'plistlib'
